# %% [markdown]
# <a href="https://colab.research.google.com/github/raiaiaia/llm-code-review-clj/blob/main/rag_experiment_mistral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Model Experiment RAG
#
# Mistral model with RAG optimization technique

# %% [markdown]
# #Instalações e importações necessárias

# %%
# %%capture
# !pip install chromadb --upgrade
# !pip install langchain.community --upgrade
# !pip install langchain --upgrade
# !pip install -q sentence_transformers \
                accelerate \
                transformers \
                bitsandbytes

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 0.2.11
# Summary: Building applications with LLMs through composability
# Home-page: https://github.com/langchain-ai/langchain
# Author:
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: aiohttp, async-timeout, langchain-core, langchain-text-splitters, langsmith, numpy, pydantic, PyYAML, requests, SQLAlchemy, tenacity
# Required-by: langchain-community

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# !huggingface-cli whoami
# Out:
# nufuturo

# %%
# %%capture
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from transformers import BertTokenizer, BertModel
from transformers import AutoTokenizer, pipeline
from langchain.vectorstores.chroma import Chroma
from huggingface_hub import InferenceClient
from time import time
import transformers
import pandas as pd
import numpy as np
import argparse
import chromadb
import torch
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Carregando os dados

# %%
df = pd.read_csv('/content/drive/MyDrive/rayanne-llm-code-review-clj/Dataset/com-filtro/filtered_by_number_of_lines.csv')
df.head()
# Out:
#                                     pull_request_url  comment_id  \
# 0  https://api.github.com/repos/adamtornhill/code...    33513420
# 1  https://api.github.com/repos/adamtornhill/code...    95127516
# 2  https://api.github.com/repos/anmonteiro/lumo/p...    87304994
# 3  https://api.github.com/repos/anmonteiro/lumo/p...    88037369
# 4  https://api.github.com/repos/anmonteiro/lumo/p...    88787684
#
#                                            diff_hunk  \
# 0  @@ -1,3 +1,5 @@+[![Build Status](https://travi...
# 1  @@ -10,52 +10,106 @@ "/some/path => G1 /anothe...
# 2  @@ -35,7 +35,7 @@ Check out `lumo -h` for usag...
# 3            @@ -0,0 +1,35 @@+import net from 'net';
# 4  @@ -75,30 +76,35 @@ function consumeBuffer(buf...
#
#                                              content  \
# 0  Ah sorry there is clearly an issue here @adamt...
# 1  The test cases are a bit too noisy. We need to...
# 2                                              :+1:
# 3                  this needs a `/* @flow */` header
# 4  can we keep the readline interface as the firs...
#
#                                    cleaned_diff_hunk  diff_lines
# 0                            [![Build Status](https:           1
# 1  (def ^:const multi-regexp-group-spec\n"^/some/...           9
# 2  2. At the root of the repository, run: `boot r...           1
# 3                             import net from 'net';           1
# 4  export function processLine(sessionId: number,...           1

# %%
df = df[df['diff_lines'] >= 5].reset_index(drop=True)

# %%
# LIMIT=5 #df.shape[0]
# df = df[:LIMIT]

# %%
print(df.shape)
# Out:
# (5105, 6)

# %% [markdown]
# #Preparando o ambiente

# %%
CHROMA_PATH = '/content/drive/MyDrive/rayanne-llm-code-review-clj/Dataset/rag/chroma_data'
db = chromadb.PersistentClient(CHROMA_PATH)
collections = db.list_collections()
print(collections)
# Out:
# [Collection(id=f8a3bfb5-c8de-4910-9d9f-d4a833007c9b, name=rag)]

# %%
# %%capture
MODEL_NAME = 'bert-base-uncased'
tokenizer = BertTokenizer.from_pretrained(MODEL_NAME)
embedding_model = BertModel.from_pretrained(MODEL_NAME)

# %%
MISTRAL_INSTRUCT= 'mistralai/Mistral-7B-Instruct-v0.2'
MISTRAL= 'mistralai/Mistral-7B-v0.1'

# %%
quantization = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16
    )

mistral_model = AutoModelForCausalLM.from_pretrained(
    MISTRAL_INSTRUCT,
    device_map="auto",
    quantization_config=quantization
)

mistral_model.eval()

mistral_tokenizer = AutoTokenizer.from_pretrained(
    MISTRAL_INSTRUCT,
    padding_side="left",
    model_max_length=4096
    )

mistral_tokenizer.pad_token = tokenizer.eos_token
# Out:
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]

# %% [markdown]
# #Utilizando RAG para otimizar as revisões com MISTRAL

# %%
def get_embedding_function(text: str) -> list:
  inputs = tokenizer(
      text,
      return_tensors="pt",
      truncation=True,
      padding=True
      ).to('cuda')

  embedding_model.to('cuda')

  with torch.no_grad():
    outputs = embedding_model(**inputs)
  embeddings = outputs.last_hidden_state.mean(dim=1).squeeze().cpu().numpy()

  return embeddings.tolist()

# %%
def create_prompt(code_snippet, context):
  return f'''
      <s>[ISNT] You are an experienced programmer in Clojure.
      Review the following code snippet and provide feedback on: readability, efficiency, maintainability, and potencial bugs.

      {code_snippet}

      ---
      Conduct your review based on the following review examples:

      {context}

      </s>

      [INST] Format your review as text with itemized concrete instructions to the author of the code. Do not add this prompt to the output. [/ISNT]
  '''

# %%
def format_prompt_mistral(code, comment_id):

  code_snippet = code
  context = ''
  query_text = get_embedding_function(code_snippet)
  collection = db.get_collection('rag')
  results = collection.query(query_text, n_results=5)

  for id in results['ids'][0]:
    reviews = collection.get(ids=[id])
    comment_id_review = reviews['metadatas'][0]['comment_id']

    if comment_id_review != comment_id:
      comment = reviews['metadatas'][0]['content']
      diff_hunk = reviews['documents'][0]
      context += f'\n The following code \n {diff_hunk}\n generates this review comment\n {comment}\n'

  return create_prompt(code_snippet=code_snippet, context=context)

# %%
t = time()

if 'model_comment' not in df.columns:
    df['model_comment'] = [None for _ in range(df.shape[0])]

start_index = 2650

#for index, row in df.iterrows():
for index, row in df.iloc[start_index:].iterrows():
  print(f'Running example {index+1}')

  prompt = format_prompt_mistral(row['cleaned_diff_hunk'], row['comment_id'])
  model_input = mistral_tokenizer(prompt, return_tensors='pt').to('cuda')

  generated_ids = mistral_model.generate(
                                **model_input,
                                 temperature=0.1,
                                 top_k=1,
                                 top_p=1.0,
                                 repetition_penalty=1.4,
                                 min_new_tokens=16,
                                 max_new_tokens=512,
                                 do_sample=True
                                )

  resp = mistral_tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]
  clean_text = resp[(len(prompt)-9):]

  df.at[index, 'model_comment'] = clean_text
  if ((index+1) % 5 == 0):
    print(f'Saving results. (current shape: {index+1})')
    df.to_csv('/content/drive/MyDrive/rayanne-llm-code-review-clj/Dataset/output/rag_model_output_2.csv', index=False)

print(f'Demanded time: {time() - t} seconds')
# Out:
# Running example 2651
# Running example 2652
# Running example 2653
# Running example 2654
# Running example 2655
# Saving results. (current shape: 2655)
# Running example 2656
# Running example 2657
# Running example 2658
# Running example 2659
# Running example 2660
# Saving results. (current shape: 2660)
# Running example 2661
# Running example 2662
# Running example 2663
# Running example 2664
# Running example 2665
# Saving results. (current shape: 2665)
# Running example 2666
# Running example 2667
# Running example 2668
# Running example 2669
# Running example 2670
# Saving results. (current shape: 2670)
# Running example 2671
# Running example 2672
# Running example 2673
# Running example 2674
# Running example 2675
# Saving results. (current shape: 2675)
# Running example 2676
# Running example 2677
# Running example 2678
# Running example 2679
# Running example 2680
# Saving results. (current shape: 2680)
# Running example 2681
# Running example 2682
# Running example 2683
# Running example 2684
# Running example 2685
# Saving results. (current shape: 2685)
# Running example 2686
# Running example 2687
# Running example 2688
# Running example 2689
# Running example 2690
# Saving results. (current shape: 2690)
# Running example 2691
# Running example 2692
# Running example 2693
# Running example 2694
# Running example 2695
# Saving results. (current shape: 2695)
# Running example 2696
# Running example 2697
# Running example 2698
# Running example 2699
# Running example 2700
# Saving results. (current shape: 2700)
# Running example 2701
# Running example 2702
# Running example 2703
# Running example 2704
# Running example 2705
# Saving results. (current shape: 2705)
# Running example 2706
# Running example 2707
# Running example 2708
# Running example 2709
# Running example 2710
# Saving results. (current shape: 2710)
# Running example 2711
# Running example 2712
# Running example 2713
# Running example 2714
# Running example 2715
# Saving results. (current shape: 2715)
# Running example 2716
# Running example 2717
# Running example 2718
# Running example 2719
# Running example 2720
# Saving results. (current shape: 2720)
# Running example 2721
# Running example 2722
# Running example 2723
# Running example 2724
# Running example 2725
# Saving results. (current shape: 2725)
# Running example 2726
# Running example 2727
# Running example 2728
# Running example 2729
# Running example 2730
# Saving results. (current shape: 2730)
# Running example 2731
# Running example 2732
# Running example 2733
# Running example 2734
# Running example 2735
# Saving results. (current shape: 2735)
# Running example 2736
# Running example 2737
# Running example 2738
# Running example 2739
# Running example 2740
# Saving results. (current shape: 2740)
# Running example 2741
# Running example 2742
# Running example 2743
# Running example 2744
# Running example 2745
# Saving results. (current shape: 2745)
# Running example 2746
# Running example 2747
# Running example 2748
# Running example 2749
# Running example 2750
# Saving results. (current shape: 2750)
# Running example 2751
# Running example 2752
# Running example 2753
# Running example 2754
# Running example 2755
# Saving results. (current shape: 2755)
# Running example 2756
# Running example 2757
# Running example 2758
# Running example 2759
# Running example 2760
# Saving results. (current shape: 2760)
# Running example 2761
# Running example 2762
# Running example 2763
# Running example 2764
# Running example 2765
# Saving results. (current shape: 2765)
# Running example 2766
# Running example 2767
# Running example 2768
# Running example 2769
# Running example 2770
# Saving results. (current shape: 2770)
# Running example 2771
# Running example 2772
# Running example 2773
# Running example 2774
# Running example 2775
# Saving results. (current shape: 2775)
# Running example 2776
# Running example 2777
# Running example 2778
# Running example 2779
# Running example 2780
# Saving results. (current shape: 2780)
# Running example 2781
# Running example 2782
# Running example 2783
# Running example 2784
# Running example 2785
# Saving results. (current shape: 2785)
# Running example 2786
# Running example 2787
# Running example 2788
# Running example 2789
# Running example 2790
# Saving results. (current shape: 2790)
# Running example 2791
# Running example 2792
# Running example 2793
# Running example 2794
# Running example 2795
# Saving results. (current shape: 2795)
# Running example 2796
# Running example 2797
# Running example 2798
# Running example 2799
# Running example 2800
# Saving results. (current shape: 2800)
# Running example 2801
# Running example 2802
# Running example 2803
# Running example 2804
# Running example 2805
# Saving results. (current shape: 2805)
# Running example 2806
# Running example 2807
# Running example 2808
# Running example 2809
# Running example 2810
# Saving results. (current shape: 2810)
# Running example 2811
# Running example 2812
# Running example 2813
# Running example 2814
# Running example 2815
# Saving results. (current shape: 2815)
# Running example 2816
# Running example 2817
# Running example 2818
# Running example 2819
# Running example 2820
# Saving results. (current shape: 2820)
# Running example 2821
# Running example 2822
# Running example 2823
# Running example 2824
# Running example 2825
# Saving results. (current shape: 2825)
# Running example 2826
# Running example 2827
# Running example 2828
# Running example 2829
# Running example 2830
# Saving results. (current shape: 2830)
# Running example 2831
# Running example 2832
# Running example 2833
# Running example 2834
# Running example 2835
# Saving results. (current shape: 2835)
# Running example 2836
# Running example 2837
# Running example 2838
# Running example 2839
# Running example 2840
# Saving results. (current shape: 2840)
# Running example 2841
# Running example 2842
# Running example 2843
# Running example 2844
# Running example 2845
# Saving results. (current shape: 2845)
# Running example 2846
# Running example 2847
# Running example 2848
# Running example 2849
# Running example 2850
# Saving results. (current shape: 2850)
# Running example 2851
# Running example 2852
# Running example 2853
# Running example 2854
# Running example 2855
# Saving results. (current shape: 2855)
# Running example 2856
# Running example 2857
# Running example 2858
# Running example 2859
# Running example 2860
# Saving results. (current shape: 2860)
# Running example 2861
# Running example 2862
# Running example 2863
# Running example 2864
# Running example 2865
# Saving results. (current shape: 2865)
# Running example 2866
# Running example 2867
# Running example 2868
# Running example 2869
# Running example 2870
# Saving results. (current shape: 2870)
# Running example 2871
# Running example 2872
# Running example 2873
# Running example 2874
# Running example 2875
# Saving results. (current shape: 2875)
# Running example 2876
# Running example 2877
# Running example 2878
# Running example 2879
# Running example 2880
# Saving results. (current shape: 2880)
# Running example 2881
# Running example 2882
# Running example 2883
# Running example 2884
# Running example 2885
# Saving results. (current shape: 2885)
# Running example 2886
# Running example 2887
# Running example 2888
# Running example 2889
# Running example 2890
# Saving results. (current shape: 2890)
# Running example 2891
# Running example 2892
# Running example 2893
# Running example 2894
# Running example 2895
# Saving results. (current shape: 2895)
# Running example 2896
# Running example 2897
# Running example 2898
# Running example 2899
# Running example 2900
# Saving results. (current shape: 2900)
# Running example 2901
# Running example 2902
# Running example 2903
# Running example 2904
# Running example 2905
# Saving results. (current shape: 2905)
# Running example 2906
# Running example 2907
# Running example 2908
# Running example 2909
# Running example 2910
# Saving results. (current shape: 2910)
# Running example 2911
# Running example 2912
# Running example 2913
# Running example 2914
# Running example 2915
# Saving results. (current shape: 2915)
# Running example 2916
# Running example 2917
# Running example 2918
# Running example 2919
# Running example 2920
# Saving results. (current shape: 2920)
# Running example 2921
# Running example 2922
# Running example 2923
# Running example 2924
# Running example 2925
# Saving results. (current shape: 2925)
# Running example 2926
# Running example 2927
# Running example 2928
# Running example 2929
# Running example 2930
# Saving results. (current shape: 2930)
# Running example 2931
# Running example 2932
# Running example 2933
# Running example 2934
# Running example 2935
# Saving results. (current shape: 2935)
# Running example 2936
# Running example 2937
# Running example 2938
# Running example 2939
# Running example 2940
# Saving results. (current shape: 2940)
# Running example 2941
# Running example 2942
# Running example 2943
# Running example 2944
# Running example 2945
# Saving results. (current shape: 2945)
# Running example 2946
# Running example 2947
# Running example 2948
# Running example 2949
# Running example 2950
# Saving results. (current shape: 2950)
# Running example 2951
# Running example 2952
# Running example 2953
# Running example 2954
# Running example 2955
# Saving results. (current shape: 2955)
# Running example 2956
# Running example 2957
# Running example 2958
# Running example 2959
# Running example 2960
# Saving results. (current shape: 2960)
# Running example 2961
# Running example 2962
# Running example 2963
# Running example 2964
# Running example 2965
# Saving results. (current shape: 2965)
# Running example 2966
# Running example 2967
# Running example 2968
# Running example 2969
# Running example 2970
# Saving results. (current shape: 2970)
# Running example 2971
# Running example 2972
# Running example 2973
# Running example 2974
# Running example 2975
# Saving results. (current shape: 2975)
# Running example 2976
# Running example 2977
# Running example 2978
# Running example 2979
# Running example 2980
# Saving results. (current shape: 2980)
# Running example 2981
# Running example 2982
# Running example 2983
# Running example 2984
# Running example 2985
# Saving results. (current shape: 2985)
# Running example 2986
# Running example 2987
# Running example 2988
# Running example 2989
# Running example 2990
# Saving results. (current shape: 2990)
# Running example 2991
# Running example 2992
# Running example 2993
# Running example 2994
# Running example 2995
# Saving results. (current shape: 2995)
# Running example 2996
# Running example 2997
# Running example 2998
# Running example 2999
# Running example 3000
# Saving results. (current shape: 3000)
# Running example 3001
# Running example 3002
# Running example 3003
# Running example 3004
# Running example 3005
# Saving results. (current shape: 3005)
# Running example 3006
# Running example 3007
# Running example 3008
# Running example 3009
# Running example 3010
# Saving results. (current shape: 3010)
# Running example 3011
# Running example 3012
# Running example 3013
# Running example 3014
# Running example 3015
# Saving results. (current shape: 3015)
# Running example 3016
# Running example 3017
# Running example 3018
# Running example 3019
# Running example 3020
# Saving results. (current shape: 3020)
# Running example 3021
# Running example 3022
# Running example 3023
# Running example 3024
# Running example 3025
# Saving results. (current shape: 3025)
# Running example 3026
# Running example 3027
# Running example 3028
# Running example 3029
# Running example 3030
# Saving results. (current shape: 3030)
# Running example 3031
# Running example 3032
# Running example 3033
# Running example 3034
# Running example 3035
# Saving results. (current shape: 3035)
# Running example 3036
# Running example 3037
# Running example 3038
# Running example 3039
# Running example 3040
# Saving results. (current shape: 3040)
# Running example 3041
# Running example 3042
# Running example 3043
# Running example 3044
# Running example 3045
# Saving results. (current shape: 3045)
# Running example 3046
# Running example 3047
# Running example 3048
# Running example 3049
# Running example 3050
# Saving results. (current shape: 3050)
# Running example 3051
# Running example 3052
# Running example 3053
# Running example 3054
# Running example 3055
# Saving results. (current shape: 3055)
# Running example 3056
# Running example 3057
# Running example 3058
# Running example 3059
# Running example 3060
# Saving results. (current shape: 3060)
# Running example 3061
# Running example 3062
# Running example 3063
# Running example 3064
# Running example 3065
# Saving results. (current shape: 3065)
# Running example 3066
# Running example 3067
# Running example 3068
# Running example 3069
# Running example 3070
# Saving results. (current shape: 3070)
# Running example 3071
# Running example 3072
# Running example 3073
# Running example 3074
# Running example 3075
# Saving results. (current shape: 3075)
# Running example 3076
# Running example 3077
# Running example 3078
# Running example 3079
# Running example 3080
# Saving results. (current shape: 3080)
# Running example 3081
# Running example 3082
# Running example 3083
# Running example 3084
# Running example 3085
# Saving results. (current shape: 3085)
# Running example 3086
# Running example 3087
# Running example 3088
# Running example 3089
# Running example 3090
# Saving results. (current shape: 3090)
# Running example 3091
# Running example 3092
# Running example 3093
# Running example 3094
# Running example 3095
# Saving results. (current shape: 3095)
# Running example 3096
# Running example 3097
# Running example 3098
# Running example 3099
# Running example 3100
# Saving results. (current shape: 3100)
# Running example 3101
# Running example 3102
# Running example 3103
# Running example 3104
# Running example 3105
# Saving results. (current shape: 3105)
# Running example 3106
# Running example 3107
# Running example 3108
# Running example 3109
# Running example 3110
# Saving results. (current shape: 3110)
# Running example 3111
# Running example 3112
# Running example 3113
# Running example 3114
# Running example 3115
# Saving results. (current shape: 3115)
# Running example 3116
# Running example 3117
# Running example 3118
# Running example 3119
# Running example 3120
# Saving results. (current shape: 3120)
# Running example 3121
# Running example 3122
# Running example 3123
# Running example 3124
# Running example 3125
# Saving results. (current shape: 3125)
# Running example 3126
# Running example 3127
# Running example 3128
# Running example 3129
# Running example 3130
# Saving results. (current shape: 3130)
# Running example 3131
# Running example 3132
# Running example 3133
# Running example 3134
# Running example 3135
# Saving results. (current shape: 3135)
# Running example 3136
# Running example 3137
# Running example 3138
# Running example 3139
# Running example 3140
# Saving results. (current shape: 3140)
# Running example 3141
# Running example 3142
# Running example 3143
# Running example 3144
# Running example 3145
# Saving results. (current shape: 3145)
# Running example 3146
# Running example 3147
# Running example 3148
# Running example 3149
# Running example 3150
# Saving results. (current shape: 3150)
# Running example 3151
# Running example 3152
# Running example 3153
# Running example 3154
# Running example 3155
# Saving results. (current shape: 3155)
# Running example 3156
# Running example 3157
# Running example 3158
# Running example 3159
# Running example 3160
# Saving results. (current shape: 3160)
# Running example 3161
# Running example 3162
# Running example 3163
# Running example 3164
# Running example 3165
# Saving results. (current shape: 3165)
# Running example 3166
# Running example 3167
# Running example 3168
# Running example 3169
# Running example 3170
# Saving results. (current shape: 3170)
# Running example 3171
# Running example 3172
# Running example 3173
# Running example 3174
# Running example 3175
# Saving results. (current shape: 3175)
# Running example 3176
# Running example 3177
# Running example 3178
# Running example 3179
# Running example 3180
# Saving results. (current shape: 3180)
# Running example 3181
# Running example 3182
# Running example 3183
# Running example 3184
# Running example 3185
# Saving results. (current shape: 3185)
# Running example 3186
# Running example 3187
# Running example 3188
# Running example 3189
# Running example 3190
# Saving results. (current shape: 3190)
# Running example 3191
# Running example 3192
# Running example 3193
# Running example 3194
# Running example 3195
# Saving results. (current shape: 3195)
# Running example 3196
# Running example 3197
# Running example 3198
# Running example 3199
# Running example 3200
# Saving results. (current shape: 3200)
# Running example 3201
# Running example 3202
# Running example 3203
# Running example 3204
# Running example 3205
# Saving results. (current shape: 3205)
# Running example 3206
# Running example 3207
# Running example 3208
# Running example 3209
# Running example 3210
# Saving results. (current shape: 3210)
# Running example 3211
# Running example 3212
# Running example 3213
# Running example 3214
# Running example 3215
# Saving results. (current shape: 3215)
# Running example 3216
# Running example 3217
# Running example 3218
# Running example 3219
# Running example 3220
# Saving results. (current shape: 3220)
# Running example 3221
# Running example 3222
# Running example 3223
# Running example 3224
# Running example 3225
# Saving results. (current shape: 3225)
# Running example 3226
# Running example 3227
# Running example 3228
# Running example 3229
# Running example 3230
# Saving results. (current shape: 3230)
# Running example 3231
# Running example 3232
# Running example 3233
# Running example 3234
# Running example 3235
# Saving results. (current shape: 3235)
# Running example 3236
# Running example 3237
# Running example 3238
# Running example 3239
# Running example 3240
# Saving results. (current shape: 3240)
# Running example 3241
# Running example 3242
# Running example 3243
# Running example 3244
# Running example 3245
# Saving results. (current shape: 3245)
# Running example 3246
# Running example 3247
# Running example 3248
# Running example 3249
# Running example 3250
# Saving results. (current shape: 3250)
# Running example 3251
# Running example 3252
# Running example 3253
# Running example 3254
# Running example 3255
# Saving results. (current shape: 3255)
# Running example 3256
# Running example 3257
# Running example 3258
# Running example 3259
# Running example 3260
# Saving results. (current shape: 3260)
# Running example 3261
# Running example 3262
# Running example 3263
# Running example 3264
# Running example 3265
# Saving results. (current shape: 3265)
# Running example 3266
# Running example 3267
# Running example 3268
# Running example 3269
# Running example 3270
# Saving results. (current shape: 3270)
# Running example 3271
# Running example 3272
# Running example 3273
# Running example 3274
# Running example 3275
# Saving results. (current shape: 3275)
# Running example 3276
# Running example 3277
# Running example 3278
# Running example 3279
# Running example 3280
# Saving results. (current shape: 3280)
# Running example 3281
# Running example 3282
# Running example 3283
# Running example 3284
# Running example 3285
# Saving results. (current shape: 3285)
# Running example 3286
# Running example 3287
# Running example 3288
# Running example 3289
# Running example 3290
# Saving results. (current shape: 3290)
# Running example 3291
# Running example 3292
# Running example 3293
# Running example 3294
# Running example 3295
# Saving results. (current shape: 3295)
# Running example 3296
# Running example 3297
# Running example 3298
# Running example 3299
# Running example 3300
# Saving results. (current shape: 3300)
# Running example 3301
# Running example 3302
# Running example 3303
# Running example 3304
# Running example 3305
# Saving results. (current shape: 3305)
# Running example 3306
# Running example 3307
# Running example 3308
# Running example 3309
# Running example 3310
# Saving results. (current shape: 3310)
# Running example 3311
# Running example 3312
# Running example 3313
# Running example 3314
# Running example 3315
# Saving results. (current shape: 3315)
# Running example 3316
# Running example 3317
# Running example 3318
# Running example 3319
# Running example 3320
# Saving results. (current shape: 3320)
# Running example 3321
# Running example 3322
# Running example 3323
# Running example 3324
# Running example 3325
# Saving results. (current shape: 3325)
# Running example 3326
# Running example 3327
# Running example 3328
# Running example 3329
# Running example 3330
# Saving results. (current shape: 3330)
# Running example 3331
# Running example 3332
# Running example 3333
# Running example 3334
# Running example 3335
# Saving results. (current shape: 3335)
# Running example 3336
# Running example 3337
# Running example 3338
# Running example 3339
# Running example 3340
# Saving results. (current shape: 3340)
# Running example 3341
# Running example 3342
# Running example 3343
# Running example 3344
# Running example 3345
# Saving results. (current shape: 3345)
# Running example 3346
# Running example 3347
# Running example 3348
# Running example 3349
# Running example 3350
# Saving results. (current shape: 3350)
# Running example 3351
# Running example 3352
# Running example 3353
# Running example 3354
# Running example 3355
# Saving results. (current shape: 3355)
# Running example 3356
# Running example 3357
# Running example 3358
# Running example 3359
# Running example 3360
# Saving results. (current shape: 3360)
# Running example 3361
# Running example 3362
# Running example 3363
# Running example 3364
# Running example 3365
# Saving results. (current shape: 3365)
# Running example 3366
# Running example 3367
# Running example 3368
# Running example 3369
# Running example 3370
# Saving results. (current shape: 3370)
# Running example 3371
# Running example 3372
# Running example 3373
# Running example 3374
# Running example 3375
# Saving results. (current shape: 3375)
# Running example 3376
# Running example 3377
# Running example 3378
# Running example 3379
# Running example 3380
# Saving results. (current shape: 3380)
# Running example 3381
# Running example 3382
# Running example 3383
# Running example 3384
# Running example 3385
# Saving results. (current shape: 3385)
# Running example 3386
# Running example 3387
# Running example 3388
# Running example 3389
# Running example 3390
# Saving results. (current shape: 3390)
# Running example 3391
# Running example 3392
# Running example 3393
# Running example 3394
# Running example 3395
# Saving results. (current shape: 3395)
# Running example 3396
# Running example 3397
# Running example 3398
# Running example 3399
# Running example 3400
# Saving results. (current shape: 3400)
# Running example 3401
# Running example 3402
# Running example 3403
# Running example 3404
# Running example 3405
# Saving results. (current shape: 3405)
# Running example 3406
# Running example 3407
# Running example 3408
# Running example 3409
# Running example 3410
# Saving results. (current shape: 3410)
# Running example 3411
# Running example 3412
# Running example 3413
# Running example 3414
# Running example 3415
# Saving results. (current shape: 3415)
# Running example 3416
# Running example 3417
# Running example 3418
# Running example 3419
# Running example 3420
# Saving results. (current shape: 3420)
# Running example 3421
# Running example 3422
# Running example 3423
# Running example 3424
# Running example 3425
# Saving results. (current shape: 3425)
# Running example 3426
# Running example 3427
# Running example 3428
# Running example 3429
# Running example 3430
# Saving results. (current shape: 3430)
# Running example 3431
# Running example 3432
# Running example 3433
# Running example 3434
# Running example 3435
# Saving results. (current shape: 3435)
# Running example 3436
# Running example 3437
# Running example 3438
# Running example 3439
# Running example 3440
# Saving results. (current shape: 3440)
# Running example 3441
# Running example 3442
# Running example 3443
# Running example 3444
# Running example 3445
# Saving results. (current shape: 3445)
# Running example 3446
# Running example 3447
# Running example 3448
# Running example 3449
# Running example 3450
# Saving results. (current shape: 3450)
# Running example 3451
# Running example 3452
# Running example 3453
# Running example 3454
# Running example 3455
# Saving results. (current shape: 3455)
# Running example 3456
# Running example 3457
# Running example 3458
# Running example 3459
# Running example 3460
# Saving results. (current shape: 3460)
# Running example 3461
# Running example 3462
# Running example 3463
# Running example 3464
# Running example 3465
# Saving results. (current shape: 3465)
# Running example 3466
# Running example 3467
# Running example 3468
# Running example 3469
# Running example 3470
# Saving results. (current shape: 3470)
# Running example 3471
# Running example 3472
# Running example 3473
# Running example 3474
# Running example 3475
# Saving results. (current shape: 3475)
# Running example 3476
# Running example 3477
# Running example 3478
# Running example 3479
# Running example 3480
# Saving results. (current shape: 3480)
# Running example 3481
# Running example 3482
# Running example 3483
# Running example 3484
# Running example 3485
# Saving results. (current shape: 3485)
# Running example 3486
# Running example 3487
# Running example 3488
# Running example 3489
# Running example 3490
# Saving results. (current shape: 3490)
# Running example 3491
# Running example 3492
# Running example 3493
# Running example 3494
# Running example 3495
# Saving results. (current shape: 3495)
# Running example 3496
# Running example 3497
# Running example 3498
# Running example 3499
# Running example 3500
# Saving results. (current shape: 3500)
# Running example 3501
# Running example 3502
# Running example 3503
# Running example 3504
# Running example 3505
# Saving results. (current shape: 3505)
# Running example 3506
# Running example 3507
# Running example 3508
# Running example 3509
# Running example 3510
# Saving results. (current shape: 3510)
# Running example 3511
# Running example 3512
# Running example 3513
# Running example 3514
# Running example 3515
# Saving results. (current shape: 3515)
# Running example 3516
# Running example 3517
# Running example 3518
# Running example 3519
# Running example 3520
# Saving results. (current shape: 3520)
# Running example 3521
# Running example 3522
# Running example 3523
# Running example 3524
# Running example 3525
# Saving results. (current shape: 3525)
# Running example 3526
# Running example 3527
# Running example 3528
# Running example 3529
# Running example 3530
# Saving results. (current shape: 3530)
# Running example 3531
# Running example 3532
# Running example 3533
# Running example 3534
# Running example 3535
# Saving results. (current shape: 3535)
# Running example 3536
# Running example 3537
# Running example 3538
# Running example 3539
# Running example 3540
# Saving results. (current shape: 3540)
# Running example 3541
# Running example 3542
# Running example 3543
# Running example 3544
# Running example 3545
# Saving results. (current shape: 3545)
# Running example 3546
# Running example 3547
# Running example 3548
# Running example 3549
# Running example 3550
# Saving results. (current shape: 3550)
# Running example 3551
# Running example 3552
# Running example 3553
# Running example 3554
# Running example 3555
# Saving results. (current shape: 3555)
# Running example 3556
# Running example 3557
# Running example 3558
# Running example 3559
# Running example 3560
# Saving results. (current shape: 3560)
# Running example 3561
# Running example 3562
# Running example 3563
# Running example 3564
# Running example 3565
# Saving results. (current shape: 3565)
# Running example 3566
# Running example 3567
# Running example 3568
# Running example 3569
# Running example 3570
# Saving results. (current shape: 3570)
# Running example 3571
# Running example 3572
# Running example 3573
# Running example 3574
# Running example 3575
# Saving results. (current shape: 3575)
# Running example 3576
# Running example 3577
# Running example 3578
# Running example 3579
# Running example 3580
# Saving results. (current shape: 3580)
# Running example 3581
# Running example 3582
# Running example 3583
# Running example 3584
# Running example 3585
# Saving results. (current shape: 3585)
# Running example 3586
# Running example 3587
# Running example 3588
# Running example 3589
# Running example 3590
# Saving results. (current shape: 3590)
# Running example 3591
# Running example 3592
# Running example 3593
# Running example 3594
# Running example 3595
# Saving results. (current shape: 3595)
# Running example 3596
# Running example 3597
# Running example 3598
# Running example 3599
# Running example 3600
# Saving results. (current shape: 3600)
# Running example 3601
# Running example 3602
# Running example 3603
# Running example 3604
# Running example 3605
# Saving results. (current shape: 3605)
# Running example 3606
# Running example 3607
# Running example 3608
# Running example 3609
# Running example 3610
# Saving results. (current shape: 3610)
# Running example 3611
# Running example 3612
# Running example 3613
# Running example 3614
# Running example 3615
# Saving results. (current shape: 3615)
# Running example 3616
# Running example 3617
# Running example 3618
# Running example 3619
# Running example 3620
# Saving results. (current shape: 3620)
# Running example 3621
# Running example 3622
# Running example 3623
# Running example 3624
# Running example 3625
# Saving results. (current shape: 3625)
# Running example 3626
# Running example 3627
# Running example 3628
# Running example 3629
# Running example 3630
# Saving results. (current shape: 3630)
# Running example 3631
# Running example 3632
# Running example 3633
# Running example 3634
# Running example 3635
# Saving results. (current shape: 3635)
# Running example 3636
# Running example 3637
# Running example 3638
# Running example 3639
# Running example 3640
# Saving results. (current shape: 3640)
# Running example 3641
# Running example 3642
# Running example 3643
# Running example 3644
# Running example 3645
# Saving results. (current shape: 3645)
# Running example 3646
# Running example 3647
# Running example 3648
# Running example 3649
# Running example 3650
# Saving results. (current shape: 3650)
# Running example 3651
# Running example 3652
# Running example 3653
# Running example 3654
# Running example 3655
# Saving results. (current shape: 3655)
# Running example 3656
# Running example 3657
# Running example 3658
# Running example 3659
# Running example 3660
# Saving results. (current shape: 3660)
# Running example 3661
# Running example 3662
# Running example 3663
# Running example 3664
# Running example 3665
# Saving results. (current shape: 3665)
# Running example 3666
# Running example 3667
# Running example 3668
# Running example 3669
# Running example 3670
# Saving results. (current shape: 3670)
# Running example 3671
# Running example 3672
# Running example 3673
# Running example 3674
# Running example 3675
# Saving results. (current shape: 3675)
# Running example 3676
# Running example 3677
# Running example 3678
# Running example 3679
# Running example 3680
# Saving results. (current shape: 3680)
# Running example 3681
# Running example 3682
# Running example 3683
# Running example 3684
# Running example 3685
# Saving results. (current shape: 3685)
# Running example 3686
# Running example 3687
# Running example 3688
# Running example 3689
# Running example 3690
# Saving results. (current shape: 3690)
# Running example 3691
# Running example 3692
# Running example 3693
# Running example 3694
# Running example 3695
# Saving results. (current shape: 3695)
# Running example 3696
# Running example 3697
# Running example 3698
# Running example 3699
# Running example 3700
# Saving results. (current shape: 3700)
# Running example 3701
# Running example 3702
# Running example 3703
# Running example 3704
# Running example 3705
# Saving results. (current shape: 3705)
# Running example 3706
# Running example 3707
# Running example 3708
# Running example 3709
# Running example 3710
# Saving results. (current shape: 3710)
# Running example 3711
# Running example 3712
# Running example 3713
# Running example 3714
# Running example 3715
# Saving results. (current shape: 3715)
# Running example 3716
# Running example 3717
# Running example 3718
# Running example 3719
# Running example 3720
# Saving results. (current shape: 3720)
# Running example 3721
# Running example 3722
# Running example 3723
# Running example 3724
# Running example 3725
# Saving results. (current shape: 3725)
# Running example 3726
# Running example 3727
# Running example 3728
# Running example 3729
# Running example 3730
# Saving results. (current shape: 3730)
# Running example 3731
# Running example 3732
# Running example 3733
# Running example 3734
# Running example 3735
# Saving results. (current shape: 3735)
# Running example 3736
# Running example 3737
# Running example 3738
# Running example 3739
# Running example 3740
# Saving results. (current shape: 3740)
# Running example 3741
# Running example 3742
# Running example 3743
# Running example 3744
# Running example 3745
# Saving results. (current shape: 3745)
# Running example 3746
# Running example 3747
# Running example 3748
# Running example 3749
# Running example 3750
# Saving results. (current shape: 3750)
# Running example 3751
# Running example 3752
# Running example 3753
# Running example 3754
# Running example 3755
# Saving results. (current shape: 3755)
# Running example 3756
# Running example 3757
# Running example 3758
# Running example 3759
# Running example 3760
# Saving results. (current shape: 3760)
# Running example 3761
# Running example 3762
# Running example 3763
# Running example 3764
# Running example 3765
# Saving results. (current shape: 3765)
# Running example 3766
# Running example 3767
# Running example 3768
# Running example 3769
# Running example 3770
# Saving results. (current shape: 3770)
# Running example 3771
# Running example 3772
# Running example 3773
# Running example 3774
# Running example 3775
# Saving results. (current shape: 3775)
# Running example 3776
# Running example 3777
# Running example 3778
# Running example 3779
# Running example 3780
# Saving results. (current shape: 3780)
# Running example 3781
# Running example 3782
# Running example 3783
# Running example 3784
# Running example 3785
# Saving results. (current shape: 3785)
# Running example 3786
# Running example 3787
# Running example 3788
# Running example 3789
# Running example 3790
# Saving results. (current shape: 3790)
# Running example 3791
# Running example 3792
# Running example 3793
# Running example 3794
# Running example 3795
# Saving results. (current shape: 3795)
# Running example 3796
# Running example 3797
# Running example 3798
# Running example 3799
# Running example 3800
# Saving results. (current shape: 3800)
# Running example 3801
# Running example 3802
# Running example 3803
# Running example 3804
# Running example 3805
# Saving results. (current shape: 3805)
# Running example 3806
# Running example 3807
# Running example 3808
# Running example 3809
# Running example 3810
# Saving results. (current shape: 3810)
# Running example 3811
# Running example 3812
# Running example 3813
# Running example 3814
# Running example 3815
# Saving results. (current shape: 3815)
# Running example 3816
# Running example 3817
# Running example 3818
# Running example 3819
# Running example 3820
# Saving results. (current shape: 3820)
# Running example 3821
# Running example 3822
# Running example 3823
# Running example 3824
# Running example 3825
# Saving results. (current shape: 3825)
# Running example 3826
# Running example 3827
# Running example 3828
# Running example 3829
# Running example 3830
# Saving results. (current shape: 3830)
# Running example 3831
# Running example 3832
# Running example 3833
# Running example 3834
# Running example 3835
# Saving results. (current shape: 3835)
# Running example 3836
# Running example 3837
# Running example 3838
# Running example 3839
# Running example 3840
# Saving results. (current shape: 3840)
# Running example 3841
# Running example 3842
# Running example 3843
# Running example 3844
# Running example 3845
# Saving results. (current shape: 3845)
# Running example 3846
# Running example 3847
# Running example 3848
# Running example 3849
# Running example 3850
# Saving results. (current shape: 3850)
# Running example 3851
# Running example 3852
# Running example 3853
# Running example 3854
# Running example 3855
# Saving results. (current shape: 3855)
# Running example 3856
# Running example 3857
# Running example 3858
# Running example 3859
# Running example 3860
# Saving results. (current shape: 3860)
# Running example 3861
# Running example 3862
# Running example 3863
# Running example 3864
# Running example 3865
# Saving results. (current shape: 3865)
# Running example 3866
# Running example 3867
# Running example 3868
# Running example 3869
# Running example 3870
# Saving results. (current shape: 3870)
# Running example 3871
# Running example 3872
# Running example 3873
# Running example 3874
# Running example 3875
# Saving results. (current shape: 3875)
# Running example 3876
# Running example 3877
# Running example 3878
# Running example 3879
# Running example 3880
# Saving results. (current shape: 3880)
# Running example 3881
# Running example 3882
# Running example 3883
# Running example 3884
# Running example 3885
# Saving results. (current shape: 3885)
# Running example 3886
# Running example 3887
# Running example 3888
# Running example 3889
# Running example 3890
# Saving results. (current shape: 3890)
# Running example 3891
# Running example 3892
# Running example 3893
# Running example 3894
# Running example 3895
# Saving results. (current shape: 3895)
# Running example 3896
# Running example 3897
# Running example 3898
# Running example 3899
# Running example 3900
# Saving results. (current shape: 3900)
# Running example 3901
# Running example 3902
# Running example 3903
# Running example 3904
# Running example 3905
# Saving results. (current shape: 3905)
# Running example 3906
# Running example 3907
# Running example 3908
# Running example 3909
# Running example 3910
# Saving results. (current shape: 3910)
# Running example 3911
# Running example 3912
# Running example 3913
# Running example 3914
# Running example 3915
# Saving results. (current shape: 3915)
# Running example 3916
# Running example 3917
# Running example 3918
# Running example 3919
# Running example 3920
# Saving results. (current shape: 3920)
# Running example 3921
# Running example 3922
# Running example 3923
# Running example 3924
# Running example 3925
# Saving results. (current shape: 3925)
# Running example 3926
# Running example 3927
# Running example 3928
# Running example 3929
# Running example 3930
# Saving results. (current shape: 3930)
# Running example 3931
# Running example 3932
# Running example 3933
# Running example 3934
# Running example 3935
# Saving results. (current shape: 3935)
# Running example 3936
# Running example 3937
# Running example 3938
# Running example 3939
# Running example 3940
# Saving results. (current shape: 3940)
# Running example 3941
# Running example 3942
# Running example 3943
# Running example 3944
# Running example 3945
# Saving results. (current shape: 3945)
# Running example 3946
# Running example 3947
# Running example 3948
# Running example 3949
# Running example 3950
# Saving results. (current shape: 3950)
# Running example 3951
# Running example 3952
# Running example 3953
# Running example 3954
# Running example 3955
# Saving results. (current shape: 3955)
# Running example 3956
# Running example 3957
# Running example 3958
# Running example 3959
# Running example 3960
# Saving results. (current shape: 3960)
# Running example 3961
# Running example 3962
# Running example 3963
# Running example 3964
# Running example 3965
# Saving results. (current shape: 3965)
# Running example 3966
# Running example 3967
# Running example 3968
# Running example 3969
# Running example 3970
# Saving results. (current shape: 3970)
# Running example 3971
# Running example 3972
# Running example 3973
# Running example 3974
# Running example 3975
# Saving results. (current shape: 3975)
# Running example 3976
# Running example 3977
# Running example 3978
# Running example 3979
# Running example 3980
# Saving results. (current shape: 3980)
# Running example 3981
# Running example 3982
# Running example 3983
# Running example 3984
# Running example 3985
# Saving results. (current shape: 3985)
# Running example 3986
# Running example 3987
# Running example 3988
# Running example 3989
# Running example 3990
# Saving results. (current shape: 3990)
# Running example 3991
# Running example 3992
# Running example 3993
# Running example 3994
# Running example 3995
# Saving results. (current shape: 3995)
# Running example 3996
# Running example 3997
# Running example 3998
# Running example 3999
# Running example 4000
# Saving results. (current shape: 4000)
# Running example 4001
# Running example 4002
# Running example 4003
# Running example 4004
# Running example 4005
# Saving results. (current shape: 4005)
# Running example 4006
# Running example 4007
# Running example 4008
# Running example 4009
# Running example 4010
# Saving results. (current shape: 4010)
# Running example 4011
# Running example 4012
# Running example 4013
# Running example 4014
# Running example 4015
# Saving results. (current shape: 4015)
# Running example 4016
# Running example 4017
# Running example 4018
# Running example 4019
# Running example 4020
# Saving results. (current shape: 4020)
# Running example 4021
# Running example 4022
# Running example 4023
# Running example 4024
# Running example 4025
# Saving results. (current shape: 4025)
# Running example 4026
# Running example 4027
# Running example 4028
# Running example 4029
# Running example 4030
# Saving results. (current shape: 4030)
# Running example 4031
# Running example 4032
# Running example 4033
# Running example 4034
# Running example 4035
# Saving results. (current shape: 4035)
# Running example 4036
# Running example 4037
# Running example 4038
# Running example 4039
# Running example 4040
# Saving results. (current shape: 4040)
# Running example 4041
# Running example 4042
# Running example 4043
# Running example 4044
# Running example 4045
# Saving results. (current shape: 4045)
# Running example 4046
# Running example 4047
# Running example 4048
# Running example 4049
# Running example 4050
# Saving results. (current shape: 4050)
# Running example 4051
# Running example 4052
# Running example 4053
# Running example 4054
# Running example 4055
# Saving results. (current shape: 4055)
# Running example 4056
# Running example 4057
# Running example 4058
# Running example 4059
# Running example 4060
# Saving results. (current shape: 4060)
# Running example 4061
# Running example 4062
# Running example 4063
# Running example 4064
# Running example 4065
# Saving results. (current shape: 4065)
# Running example 4066
# Running example 4067
# Running example 4068
# Running example 4069
# Running example 4070
# Saving results. (current shape: 4070)
# Running example 4071
# Running example 4072
# Running example 4073
# Running example 4074
# Running example 4075
# Saving results. (current shape: 4075)
# Running example 4076
# Running example 4077
# Running example 4078
# Running example 4079
# Running example 4080
# Saving results. (current shape: 4080)
# Running example 4081
# Running example 4082
# Running example 4083
# Running example 4084
# Running example 4085
# Saving results. (current shape: 4085)
# Running example 4086
# Running example 4087
# Running example 4088
# Running example 4089
# Running example 4090
# Saving results. (current shape: 4090)
# Running example 4091
# Running example 4092
# Running example 4093
# Running example 4094
# Running example 4095
# Saving results. (current shape: 4095)
# Running example 4096
# Running example 4097
# Running example 4098
# Running example 4099
# Running example 4100
# Saving results. (current shape: 4100)
# Running example 4101
# Running example 4102
# Running example 4103
# Running example 4104
# Running example 4105
# Saving results. (current shape: 4105)
# Running example 4106
# Running example 4107
# Running example 4108
# Running example 4109
# Running example 4110
# Saving results. (current shape: 4110)
# Running example 4111
# Running example 4112
# Running example 4113
# Running example 4114
# Running example 4115
# Saving results. (current shape: 4115)
# Running example 4116
# Running example 4117
# Running example 4118
# Running example 4119
# Running example 4120
# Saving results. (current shape: 4120)
# Running example 4121
# Running example 4122
# Running example 4123
# Running example 4124
# Running example 4125
# Saving results. (current shape: 4125)
# Running example 4126
# Running example 4127
# Running example 4128
# Running example 4129
# Running example 4130
# Saving results. (current shape: 4130)
# Running example 4131
# Running example 4132
# Running example 4133
# Running example 4134
# Running example 4135
# Saving results. (current shape: 4135)
# Running example 4136
# Running example 4137
# Running example 4138
# Running example 4139
# Running example 4140
# Saving results. (current shape: 4140)
# Running example 4141
# Running example 4142
# Running example 4143
# Running example 4144
# Running example 4145
# Saving results. (current shape: 4145)
# Running example 4146
# Running example 4147
# Running example 4148
# Running example 4149
# Running example 4150
# Saving results. (current shape: 4150)
# Running example 4151
# Running example 4152
# Running example 4153
# Running example 4154
# Running example 4155
# Saving results. (current shape: 4155)
# Running example 4156
# Running example 4157
# Running example 4158
# Running example 4159
# Running example 4160
# Saving results. (current shape: 4160)
# Running example 4161
# Running example 4162
# Running example 4163
# Running example 4164
# Running example 4165
# Saving results. (current shape: 4165)
# Running example 4166
# Running example 4167
# Running example 4168
# Running example 4169
# Running example 4170
# Saving results. (current shape: 4170)
# Running example 4171
# Running example 4172
# Running example 4173
# Running example 4174
# Running example 4175
# Saving results. (current shape: 4175)
# Running example 4176
# Running example 4177
# Running example 4178
# Running example 4179
# Running example 4180
# Saving results. (current shape: 4180)
# Running example 4181
# Running example 4182
# Running example 4183
# Running example 4184
# Running example 4185
# Saving results. (current shape: 4185)
# Running example 4186
# Running example 4187
# Running example 4188
# Running example 4189
# Running example 4190
# Saving results. (current shape: 4190)
# Running example 4191
# Running example 4192
# Running example 4193
# Running example 4194
# Running example 4195
# Saving results. (current shape: 4195)
# Running example 4196
# Running example 4197
# Running example 4198
# Running example 4199
# Running example 4200
# Saving results. (current shape: 4200)
# Running example 4201
# Running example 4202
# Running example 4203
# Running example 4204
# Running example 4205
# Saving results. (current shape: 4205)
# Running example 4206
# Running example 4207
# Running example 4208
# Running example 4209
# Running example 4210
# Saving results. (current shape: 4210)
# Running example 4211
# Running example 4212
# Running example 4213
# Running example 4214
# Running example 4215
# Saving results. (current shape: 4215)
# Running example 4216
# Running example 4217
# Running example 4218
# Running example 4219
# Running example 4220
# Saving results. (current shape: 4220)
# Running example 4221
# Running example 4222
# Running example 4223
# Running example 4224
# Running example 4225
# Saving results. (current shape: 4225)
# Running example 4226
# Running example 4227
# Running example 4228
# Running example 4229
# Running example 4230
# Saving results. (current shape: 4230)
# Running example 4231
# Running example 4232
# Running example 4233
# Running example 4234
# Running example 4235
# Saving results. (current shape: 4235)
# Running example 4236
# Running example 4237
# Running example 4238
# Running example 4239
# Running example 4240
# Saving results. (current shape: 4240)
# Running example 4241
# Running example 4242
# Running example 4243
# Running example 4244
# Running example 4245
# Saving results. (current shape: 4245)
# Running example 4246
# Running example 4247
# Running example 4248
# Running example 4249
# Running example 4250
# Saving results. (current shape: 4250)
# Running example 4251
# Running example 4252
# Running example 4253
# Running example 4254
# Running example 4255
# Saving results. (current shape: 4255)
# Running example 4256
# Running example 4257
# Running example 4258
# Running example 4259
# Running example 4260
# Saving results. (current shape: 4260)
# Running example 4261
# Running example 4262
# Running example 4263
# Running example 4264
# Running example 4265
# Saving results. (current shape: 4265)
# Running example 4266
# Running example 4267
# Running example 4268
# Running example 4269
# Running example 4270
# Saving results. (current shape: 4270)
# Running example 4271
# Running example 4272
# Running example 4273
# Running example 4274
# Running example 4275
# Saving results. (current shape: 4275)
# Running example 4276
# Running example 4277
# Running example 4278
# Running example 4279
# Running example 4280
# Saving results. (current shape: 4280)
# Running example 4281
# Running example 4282
# Running example 4283
# Running example 4284
# Running example 4285
# Saving results. (current shape: 4285)
# Running example 4286
# Running example 4287
# Running example 4288
# Running example 4289
# Running example 4290
# Saving results. (current shape: 4290)
# Running example 4291
# Running example 4292
# Running example 4293
# Running example 4294
# Running example 4295
# Saving results. (current shape: 4295)
# Running example 4296
# Running example 4297
# Running example 4298
# Running example 4299
# Running example 4300
# Saving results. (current shape: 4300)
# Running example 4301
# Running example 4302
# Running example 4303
# Running example 4304
# Running example 4305
# Saving results. (current shape: 4305)
# Running example 4306
# Running example 4307
# Running example 4308
# Running example 4309
# Running example 4310
# Saving results. (current shape: 4310)
# Running example 4311
# Running example 4312
# Running example 4313
# Running example 4314
# Running example 4315
# Saving results. (current shape: 4315)
# Running example 4316
# Running example 4317
# Running example 4318
# Running example 4319
# Running example 4320
# Saving results. (current shape: 4320)
# Running example 4321
# Running example 4322
# Running example 4323
# Running example 4324
# Running example 4325
# Saving results. (current shape: 4325)
# Running example 4326
# Running example 4327
# Running example 4328
# Running example 4329
# ...
# Running example 4549
# Running example 4550
# Saving results. (current shape: 4550)
# Running example 4551
# Running example 4552
# Running example 4553
# Running example 4554
# Running example 4555
# Saving results. (current shape: 4555)
# Running example 4556
# Running example 4557
# Running example 4558
# Running example 4559
# Running example 4560
# Saving results. (current shape: 4560)
# Running example 4561
# Running example 4562
# Running example 4563
# Running example 4564
# Running example 4565
# Saving results. (current shape: 4565)
# Running example 4566
# Running example 4567
# Running example 4568
# Running example 4569
# Running example 4570
# Saving results. (current shape: 4570)
# Running example 4571
# Running example 4572
# Running example 4573
# Running example 4574
# Running example 4575
# Saving results. (current shape: 4575)
# Running example 4576
# Running example 4577
# Running example 4578
# Running example 4579
# Running example 4580
# Saving results. (current shape: 4580)
# Running example 4581
# Running example 4582
# Running example 4583
# Running example 4584
# Running example 4585
# Saving results. (current shape: 4585)
# Running example 4586
# Running example 4587
# Running example 4588
# Running example 4589
# Running example 4590
# Saving results. (current shape: 4590)
# Running example 4591
# Running example 4592
# Running example 4593
# Running example 4594
# Running example 4595
# Saving results. (current shape: 4595)
# Running example 4596
# Running example 4597
# Running example 4598
# Running example 4599
# Running example 4600
# Saving results. (current shape: 4600)
# Running example 4601
# Running example 4602
# Running example 4603
# Running example 4604
# Running example 4605
# Saving results. (current shape: 4605)
# Running example 4606
# Running example 4607
# Running example 4608
# Running example 4609
# Running example 4610
# Saving results. (current shape: 4610)
# Running example 4611
# Running example 4612
# Running example 4613
# Running example 4614
# Running example 4615
# Saving results. (current shape: 4615)
# Running example 4616
# Running example 4617
# Running example 4618
# Running example 4619
# Running example 4620
# Saving results. (current shape: 4620)
# Running example 4621
# Running example 4622
# Running example 4623
# Running example 4624
# Running example 4625
# Saving results. (current shape: 4625)
# Running example 4626
# Running example 4627
# Running example 4628
# Running example 4629
# Running example 4630
# Saving results. (current shape: 4630)
# Running example 4631
# Running example 4632
# Running example 4633
# Running example 4634
# Running example 4635
# Saving results. (current shape: 4635)
# Running example 4636
# Running example 4637
# Running example 4638
# Running example 4639
# Running example 4640
# Saving results. (current shape: 4640)
# Running example 4641
# Running example 4642
# Running example 4643
# Running example 4644
# Running example 4645
# Saving results. (current shape: 4645)
# Running example 4646
# Running example 4647
# Running example 4648
# Running example 4649
# Running example 4650
# Saving results. (current shape: 4650)
# Running example 4651
# Running example 4652
# Running example 4653
# Running example 4654
# Running example 4655
# Saving results. (current shape: 4655)
# Running example 4656
# Running example 4657
# Running example 4658
# Running example 4659
# Running example 4660
# Saving results. (current shape: 4660)
# Running example 4661
# Running example 4662
# Running example 4663
# Running example 4664
# Running example 4665
# Saving results. (current shape: 4665)
# Running example 4666
# Running example 4667
# Running example 4668
# Running example 4669
# Running example 4670
# Saving results. (current shape: 4670)
# Running example 4671
# Running example 4672
# Running example 4673
# Running example 4674
# Running example 4675
# Saving results. (current shape: 4675)
# Running example 4676
# Running example 4677
# Running example 4678
# Running example 4679
# Running example 4680
# Saving results. (current shape: 4680)
# Running example 4681
# Running example 4682
# Running example 4683
# Running example 4684
# Running example 4685
# Saving results. (current shape: 4685)
# Running example 4686
# Running example 4687
# Running example 4688
# Running example 4689
# Running example 4690
# Saving results. (current shape: 4690)
# Running example 4691
# Running example 4692
# Running example 4693
# Running example 4694
# Running example 4695
# Saving results. (current shape: 4695)
# Running example 4696
# Running example 4697
# Running example 4698
# Running example 4699
# Running example 4700
# Saving results. (current shape: 4700)
# Running example 4701
# Running example 4702
# Running example 4703
# Running example 4704
# Running example 4705
# Saving results. (current shape: 4705)
# Running example 4706
# Running example 4707
# Running example 4708
# Running example 4709
# Running example 4710
# Saving results. (current shape: 4710)
# Running example 4711
# Running example 4712
# Running example 4713
# Running example 4714
# Running example 4715
# Saving results. (current shape: 4715)
# Running example 4716
# Running example 4717
# Running example 4718
# Running example 4719
# Running example 4720
# Saving results. (current shape: 4720)
# Running example 4721
# Running example 4722
# Running example 4723
# Running example 4724
# Running example 4725
# Saving results. (current shape: 4725)
# Running example 4726
# Running example 4727
# Running example 4728
# Running example 4729
# Running example 4730
# Saving results. (current shape: 4730)
# Running example 4731
# Running example 4732
# Running example 4733
# Running example 4734
# Running example 4735
# Saving results. (current shape: 4735)
# Running example 4736
# Running example 4737
# Running example 4738
# Running example 4739
# Running example 4740
# Saving results. (current shape: 4740)
# Running example 4741
# Running example 4742
# Running example 4743
# Running example 4744
# Running example 4745
# Saving results. (current shape: 4745)
# Running example 4746
# Running example 4747
# Running example 4748
# Running example 4749
# Running example 4750
# Saving results. (current shape: 4750)
# Running example 4751
# Running example 4752
# Running example 4753
# Running example 4754
# Running example 4755
# Saving results. (current shape: 4755)
# Running example 4756
# Running example 4757
# Running example 4758
# Running example 4759
# Running example 4760
# Saving results. (current shape: 4760)
# Running example 4761
# Running example 4762
# Running example 4763
# Running example 4764
# Running example 4765
# Saving results. (current shape: 4765)
# Running example 4766
# Running example 4767
# Running example 4768
# Running example 4769
# Running example 4770
# Saving results. (current shape: 4770)
# Running example 4771
# Running example 4772
# Running example 4773
# Running example 4774
# Running example 4775
# Saving results. (current shape: 4775)
# Running example 4776
# Running example 4777
# Running example 4778
# Running example 4779
# Running example 4780
# Saving results. (current shape: 4780)
# Running example 4781
# Running example 4782
# Running example 4783
# Running example 4784
# Running example 4785
# Saving results. (current shape: 4785)
# Running example 4786
# Running example 4787
# Running example 4788
# Running example 4789
# Running example 4790
# Saving results. (current shape: 4790)
# Running example 4791
# Running example 4792
# Running example 4793
# Running example 4794
# Running example 4795
# Saving results. (current shape: 4795)
# Running example 4796
# Running example 4797
# Running example 4798
# Running example 4799
# Running example 4800
# Saving results. (current shape: 4800)
# Running example 4801
# Running example 4802
# Running example 4803
# Running example 4804
# Running example 4805
# Saving results. (current shape: 4805)
# Running example 4806
# Running example 4807
# Running example 4808
# Running example 4809
# Running example 4810
# Saving results. (current shape: 4810)
# Running example 4811
# Running example 4812
# Running example 4813
# Running example 4814
# Running example 4815
# Saving results. (current shape: 4815)
# Running example 4816
# Running example 4817
# Running example 4818
# Running example 4819
# Running example 4820
# Saving results. (current shape: 4820)
# Running example 4821
# Running example 4822
# Running example 4823
# Running example 4824
# Running example 4825
# Saving results. (current shape: 4825)
# Running example 4826
# Running example 4827
# Running example 4828
# Running example 4829
# Running example 4830
# Saving results. (current shape: 4830)
# Running example 4831
# Running example 4832
# Running example 4833
# Running example 4834
# Running example 4835
# Saving results. (current shape: 4835)
# Running example 4836
# Running example 4837
# Running example 4838
# Running example 4839
# Running example 4840
# Saving results. (current shape: 4840)
# Running example 4841
# Running example 4842
# Running example 4843
# Running example 4844
# Running example 4845
# Saving results. (current shape: 4845)
# Running example 4846
# Running example 4847
# Running example 4848
# Running example 4849
# Running example 4850
# Saving results. (current shape: 4850)
# Running example 4851
# Running example 4852
# Running example 4853
# Running example 4854
# Running example 4855
# Saving results. (current shape: 4855)
# Running example 4856
# Running example 4857
# Running example 4858
# Running example 4859
# Running example 4860
# Saving results. (current shape: 4860)
# Running example 4861
# Running example 4862
# Running example 4863
# Running example 4864
# Running example 4865
# Saving results. (current shape: 4865)
# Running example 4866
# Running example 4867
# Running example 4868
# Running example 4869
# Running example 4870
# Saving results. (current shape: 4870)
# Running example 4871
# Running example 4872
# Running example 4873
# Running example 4874
# Running example 4875
# Saving results. (current shape: 4875)
# Running example 4876
# Running example 4877
# Running example 4878
# Running example 4879
# Running example 4880
# Saving results. (current shape: 4880)
# Running example 4881
# Running example 4882
# Running example 4883
# Running example 4884
# Running example 4885
# Saving results. (current shape: 4885)
# Running example 4886
# Running example 4887
# Running example 4888
# Running example 4889
# Running example 4890
# Saving results. (current shape: 4890)
# Running example 4891
# Running example 4892
# Running example 4893
# Running example 4894
# Running example 4895
# Saving results. (current shape: 4895)
# Running example 4896
# Running example 4897
# Running example 4898
# Running example 4899
# Running example 4900
# Saving results. (current shape: 4900)
# Running example 4901
# Running example 4902
# Running example 4903
# Running example 4904
# Running example 4905
# Saving results. (current shape: 4905)
# Running example 4906
# Running example 4907
# Running example 4908
# Running example 4909
# Running example 4910
# Saving results. (current shape: 4910)
# Running example 4911
# Running example 4912
# Running example 4913
# Running example 4914
# Running example 4915
# Saving results. (current shape: 4915)
# Running example 4916
# Running example 4917
# Running example 4918
# Running example 4919
# Running example 4920
# Saving results. (current shape: 4920)
# Running example 4921
# Running example 4922
# Running example 4923
# Running example 4924
# Running example 4925
# Saving results. (current shape: 4925)
# Running example 4926
# Running example 4927
# Running example 4928
# Running example 4929
# Running example 4930
# Saving results. (current shape: 4930)
# Running example 4931
# Running example 4932
# Running example 4933
# Running example 4934
# Running example 4935
# Saving results. (current shape: 4935)
# Running example 4936
# Running example 4937
# Running example 4938
# Running example 4939
# Running example 4940
# Saving results. (current shape: 4940)
# Running example 4941
# Running example 4942
# Running example 4943
# Running example 4944
# Running example 4945
# Saving results. (current shape: 4945)
# Running example 4946
# Running example 4947
# Running example 4948
# Running example 4949
# Running example 4950
# Saving results. (current shape: 4950)
# Running example 4951
# Running example 4952
# Running example 4953
# Running example 4954
# Running example 4955
# Saving results. (current shape: 4955)
# Running example 4956
# Running example 4957
# Running example 4958
# Running example 4959
# Running example 4960
# Saving results. (current shape: 4960)
# Running example 4961
# Running example 4962
# Running example 4963
# Running example 4964
# Running example 4965
# Saving results. (current shape: 4965)
# Running example 4966
# Running example 4967
# Running example 4968
# Running example 4969
# Running example 4970
# Saving results. (current shape: 4970)
# Running example 4971
# Running example 4972
# Running example 4973
# Running example 4974
# Running example 4975
# Saving results. (current shape: 4975)
# Running example 4976
# Running example 4977
# Running example 4978
# Running example 4979
# Running example 4980
# Saving results. (current shape: 4980)
# Running example 4981
# Running example 4982
# Running example 4983
# Running example 4984
# Running example 4985
# Saving results. (current shape: 4985)
# Running example 4986
# Running example 4987
# Running example 4988
# Running example 4989
# Running example 4990
# Saving results. (current shape: 4990)
# Running example 4991
# Running example 4992
# Running example 4993
# Running example 4994
# Running example 4995
# Saving results. (current shape: 4995)
# Running example 4996
# Running example 4997
# Running example 4998
# Running example 4999
# Running example 5000
# Saving results. (current shape: 5000)
# Running example 5001
# Running example 5002
# Running example 5003
# Running example 5004
# Running example 5005
# Saving results. (current shape: 5005)
# Running example 5006
# Running example 5007
# Running example 5008
# Running example 5009
# Running example 5010
# Saving results. (current shape: 5010)
# Running example 5011
# Running example 5012
# Running example 5013
# Running example 5014
# Running example 5015
# Saving results. (current shape: 5015)
# Running example 5016
# Running example 5017
# Running example 5018
# Running example 5019
# Running example 5020
# Saving results. (current shape: 5020)
# Running example 5021
# Running example 5022
# Running example 5023
# Running example 5024
# Running example 5025
# Saving results. (current shape: 5025)
# Running example 5026
# Running example 5027
# Running example 5028
# Running example 5029
# Running example 5030
# Saving results. (current shape: 5030)
# Running example 5031
# Running example 5032
# Running example 5033
# Running example 5034
# Running example 5035
# Saving results. (current shape: 5035)
# Running example 5036
# Running example 5037
# Running example 5038
# Running example 5039
# Running example 5040
# Saving results. (current shape: 5040)
# Running example 5041
# Running example 5042
# Running example 5043
# Running example 5044
# Running example 5045
# Saving results. (current shape: 5045)
# Running example 5046
# Running example 5047
# Running example 5048
# Running example 5049
# Running example 5050
# Saving results. (current shape: 5050)
# Running example 5051
# Running example 5052
# Running example 5053
# Running example 5054
# Running example 5055
# Saving results. (current shape: 5055)
# Running example 5056
# Running example 5057
# Running example 5058
# Running example 5059
# Running example 5060
# Saving results. (current shape: 5060)
# Running example 5061
# Running example 5062
# Running example 5063
# Running example 5064
# Running example 5065
# Saving results. (current shape: 5065)
# Running example 5066
# Running example 5067
# Running example 5068
# Running example 5069
# Running example 5070
# Saving results. (current shape: 5070)
# Running example 5071
# Running example 5072
# Running example 5073
# Running example 5074
# Running example 5075
# Saving results. (current shape: 5075)
# Running example 5076
# Running example 5077
# Running example 5078
# Running example 5079
# Running example 5080
# Saving results. (current shape: 5080)
# Running example 5081
# Running example 5082
# Running example 5083
# Running example 5084
# Running example 5085
# Saving results. (current shape: 5085)
# Running example 5086
# Running example 5087
# Running example 5088
# Running example 5089
# Running example 5090
# Saving results. (current shape: 5090)
# Running example 5091
# Running example 5092
# Running example 5093
# Running example 5094
# Running example 5095
# Saving results. (current shape: 5095)
# Running example 5096
# Running example 5097
# Running example 5098
# Running example 5099
# Running example 5100
# Saving results. (current shape: 5100)
# Running example 5101
# Running example 5102
# Running example 5103
# Running example 5104
# Running example 5105
# Saving results. (current shape: 5105)
# Demanded time: 77764.0339140892 seconds

# %% [markdown]
# #Úteis

# %%
# documento_id = "3232"
# documento = collection.get(ids=[documento_id])

# if documento:
#     print("Documento encontrado:")
#     print(documento)
# else:
#     print("Documento não encontrado.")

# %%
# from numba import cuda
# device = cuda.get_current_device()
# device.reset()

# %%
# import torch
# torch.cuda.empty_cache()

# %%
# documento_id = "3232"
# documento = collection.get(ids=[documento_id])
# #print(documento['metadatas'][0]['content'])  #comentario
# print(documento['documents'][0]) #diff_hunk
# #print(documento)

# %%
# diff_test = """
#    (:require [quo.react-native :as rn]
#              [quo2.components.tabs.tab :as tab]
#              [reagent.core :as reagent]
#              [status-im.ui.components.react :as react]
#              [status-im.utils.number :as number-utils]))

#   (def default-tab-size 32)
#      (fn [{:keys [data size] :or {size default-tab-size}}]
#             # [rn/view {:margin-right (if (= size default-tab-size) 12 8)
# """
# comment_id_test = '986675555'
# print(format_prompt_mistral(diff_test, comment_id_test))

# %%
# df = df[df['diff_lines']>=5].reset_index(drop=True)
# LIMIT=10 #df.shape[0]
# df = df[:LIMIT]
# df.head()
